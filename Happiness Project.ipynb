# %% [markdown]
# # World Happiness Report

# %% [markdown]
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %% [markdown]
# The happiness scores and rankings use data from the Gallup World Poll. The scores are based on answers to the main life evaluation question asked in the poll. This question, known as the Cantril ladder, asks respondents to think of a ladder with the best possible life for them being a 10 and the worst possible life being a 0 and to rate their own current lives on that scale. The scores are from nationally representative samples for the years 2013-2016 and use the Gallup weights to make the estimates representative. The columns following the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity – contribute to making life evaluations higher in each country than they are in Dystopia, a hypothetical country that has values equal to the world’s lowest national averages for each of the six factors. They have no impact on the total score reported for each country, but they do explain why some countries rank higher than others.

# %%
import pandas as pd

# %%
happiness=pd.read_csv("happiness.csv")
happiness.head(11)
# Out:
#         Country                           Region  Happiness Rank  \
# 0   Switzerland                   Western Europe               1
# 1       Iceland                   Western Europe               2
# 2       Denmark                   Western Europe               3
# 3        Norway                   Western Europe               4
# 4        Canada                    North America               5
# 5       Finland                   Western Europe               6
# 6   Netherlands                   Western Europe               7
# 7        Sweden                   Western Europe               8
# 8   New Zealand        Australia and New Zealand               9
# 9     Australia        Australia and New Zealand              10
# 10       Israel  Middle East and Northern Africa              11
#
#     Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0             7.587         0.03411                   1.39651  1.34951
# ...

# %%
happiness.shape
# Out:
# (158, 12)

# %%
happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
happiness["Happiness Score"].unique()
# Out:
# array([7.587, 7.561, 7.527, 7.522, 7.427, 7.406, 7.378, 7.364, 7.286,
#        7.284, 7.278, 7.226, 7.2  , 7.187, 7.119, 6.983, 6.946, 6.94 ,
#        6.937, 6.901, 6.867, 6.853, 6.81 , 6.798, 6.786, 6.75 , 6.67 ,
#        6.611, 6.575, 6.574, 6.505, 6.485, 6.477, 6.455, 6.411, 6.329,
#        6.302, 6.298, 6.295, 6.269, 6.168, 6.13 , 6.123, 6.003, 5.995,
#        5.987, 5.984, 5.975, 5.96 , 5.948, 5.89 , 5.889, 5.878, 5.855,
#        5.848, 5.833, 5.828, 5.824, 5.813, 5.791, 5.77 , 5.759, 5.754,
#        5.716, 5.709, 5.695, 5.689, 5.605, 5.589, 5.548, 5.477, 5.474,
#        5.429, 5.399, 5.36 , 5.332, 5.286, 5.268, 5.253, 5.212, 5.194,
#        5.192, 5.14 , 5.129, 5.124, 5.123, 5.102, 5.098, 5.073, 5.057,
#        5.013, 5.007, 4.971, 4.959, 4.949, 4.898, 4.885, 4.876, 4.874,
#        4.867, 4.857, 4.839, 4.8  , 4.788, 4.786, 4.739, 4.715, 4.694,
#        4.686, 4.681, 4.677, 4.642, 4.633, 4.61 , 4.571, 4.565, 4.55 ,
# ...

# %%
pd.DataFrame(happiness["Happiness Score"].value_counts())
# Out:
#        Happiness Score
# 5.192                2
# 4.642                1
# 5.098                1
# 5.129                1
# 5.889                1
# ...                ...
# 4.252                1
# 4.633                1
# 3.931                1
# 7.200                1
# 6.750                1
#
# [157 rows x 1 columns]

# %% [markdown]
# # About the columns:

# %% [markdown]
# Country:
#
# Name of the country.

# %% [markdown]
# Region:
#
# Region the country belongs to.

# %% [markdown]
# Happiness Rank:
#
# Rank of the country based on the Happiness Score.

# %% [markdown]
# Happiness Score:
#
# A metric measured in 2015 by asking the sampled people the question: "How would you rate your happiness on a.

# %% [markdown]
# Happiness Score:
#
# A metric measured in 2015 by asking the sampled people the question: "How would you rate your happiness on a.

# %% [markdown]
# Standard Error:
#
# The standard error of the happiness score.

# %% [markdown]
# Economy (GDP per Capita):
#
# The extent to which GDP contributes to the calculation of the Happiness Score.

# %% [markdown]
# Family:
#
# The extent to which Family contributes to the calculation of the Happiness Score.

# %% [markdown]
# ealth (Life Expectancy):
#
#
# The extent to which Life expectancy contributed to the calculation of the Happiness Score.

# %% [markdown]
# Freedom:
#
#
# The extent to which Freedom contributed to the calculation of the Happiness Score.

# %% [markdown]
# Trust (Government Corruption):
#
#
# The extent to which Perception of Corruption contributes to Happiness Score.

# %% [markdown]
# if we drop some column from the "Country","Region" and "Happiness Rank" than there is no effective on dataset bcoz these are having object datatype.

# %%
happiness.drop("Country",axis=1,inplace=True)
happiness.drop("Region",axis=1,inplace=True)
happiness.drop("Happiness Rank",axis=1,inplace=True)

# %%
happiness.isnull().sum()
# Out:
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5,5))
sns.heatmap(happiness.isnull())
plt.show()

# %% [markdown]
# # EDA(EXPLORATORY DATA ANALYSIS):

# %% [markdown]
# # Scatterplot:

# %%
for i in happiness:
    plt.figure(figsize=(7,8))
    sns.stripplot(x=happiness[i],y="Happiness Score",data=happiness)
    plt.show()

# %% [markdown]
# From the scatter plot we got that if the x variable is incresed than y variable are also increased linearely (from 0 to 9).

# %% [markdown]
# # Correlation:

# %%
happiness_corr=happiness.corr()

# %%
happiness_corr
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.177254
# Standard Error                       -0.177254        1.000000
# Economy (GDP per Capita)              0.780966       -0.217651
# Family                                0.740605       -0.120728
# Health (Life Expectancy)              0.724200       -0.310287
# Freedom                               0.568211       -0.129773
# Trust (Government Corruption)         0.395199       -0.178325
# Generosity                            0.180319       -0.088439
# Dystopia Residual                     0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780966  0.740605
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# ...

# %% [markdown]
# correlation with heatmap():

# %%
plt.figure(figsize=(15,7))
sns.heatmap(happiness_corr,annot=True,linewidths=0.5,linecolor="black",fmt=".2f")
plt.show()

# %% [markdown]
# From this we conclude that the "Economy" and "Family" are highely correlated with "Happiness Score".

# %% [markdown]
# Standere error make 18 percent correlation with happiness_score that is considered as weak bond.economy,family and health life made a strong bond that is (70+ percent) with happiness_score similarly the freedom trust generosity and dystopia residual make stron bond with happiness score.

# %%
happiness.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       158.000000      158.000000                158.000000  158.000000
# mean          5.375734        0.047885                  0.846137    0.991046
# std           1.145010        0.017146                  0.403121    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.526000        0.037268                  0.545808    0.856823
# 50%           5.232500        0.043940                  0.910245    1.029510
# 75%           6.243750        0.052300                  1.158448    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# ...

# %% [markdown]
# # Outcome of describing of dataset:

# %% [markdown]
# from above plotting we are determining mean,standered deviation,minimum and maximum value of each column.it helps us furtherin data cleaning.
#
# 158 rows
# 9 columns
#
# Happiness Score:
# mean:1.65,
# std:0.22,
# min:1.04,
# 25%:1.5,
# 50%:1.65,
# 75%:1.83,
# max:2.02,
#
# Standard Error:
# mean:-3.09,
# std:0.31,
# min:-3.99,
# 25%:-3.28,
# 50%:-3.12,
# 75%:-2.95,
# max:-1.98,
#
# Economy (GDP per Capita):
# mean:0.84,
# std:0.40,
# min:0.00,
# 25%:0.54,
# 50%:0.91,
# 75%:1.15,
# max:1.69,
#
# Family:
# mean:0.99,
# std:0.27,
# min:0.00,
# 25%:0.85,
# 50%:1.02,
# 75%:1.21,
# max:1.40,
#
# Health (Life Expectancy):
# mean:0.63,
# std:0.24,
# min:0.00,
# 25%:0.43,
# 50%:0.69,
# 75%:0.81,
# max:1.02,
#
# Freedom:
# mean:0.42,
# std:0.15,
# min:0.00,
# 25%:0.32,
# 50%:0.43,
# 75%:0.54,
# max:0.66,
#
# Trust (Government Corruption):
# mean:0.14,
# std:0.12,
# min:0.00,
# 25%:0.06,
# 50%:0.10,
# 75%:0.18,
# max:0.55,
#
# Generosity:
# mean:0.23,
# std:0.12,
# min:0.00,
# 25%:0.15,
# 50%:0.21,
# 75%:0.30,
# max:0.79,
#
# Dystopia Residual:
# mean:2.0,
# std:0.5,
# min:0.3,
# 25%:1.7,
# 50%:2.09,
# 75%:2.4,
# max:3.6,

# %% [markdown]
# # Outlire Checking:

# %%
happiness.boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# From the above we see there are some outlire are present inside the dataset.
#
# more outiler: (Standered Error)
#
# less outlire: (Generosity)

# %% [markdown]
# # Skewness:

# %%
happiness.skew()
# Out:
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# # Normal Dtstributed curve:

# %%
for i in happiness:
    plt.figure(figsize=(5,5))
    sns.distplot(happiness[i])
    plt.show()

# %% [markdown]
# From above result we get that the data is not normalised bcoz the building bloks are out of normalised curve.
# the normal distribution curve outcome are irrelivent.

# %% [markdown]
# # Data Cleaning:

# %%
happiness
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# # Removing outlire:

# %% [markdown]
# Z-Score techinque:

# %%
import numpy as np
from scipy.stats import zscore
z=np.abs(zscore(happiness))
z
# Out:
# array([[1.93736005, 0.80592569, 1.36962124, ..., 2.30965159, 0.47103971,
#         0.75825809],
#        [1.91458063, 0.05588945, 1.13522625, ..., 0.01647953, 1.57585637,
#         1.09285682],
#        [1.88479215, 0.8544869 , 1.19286069, ..., 2.8427738 , 0.8242928 ,
#         0.71233526],
#        ...,
#        [2.0761992 , 0.13253425, 0.45524543, ..., 0.38141902, 1.85689094,
#         3.20843049],
#        [2.1646885 , 2.26396166, 2.06756644, ..., 0.35771452, 0.31694987,
#         0.48198451],
#        [2.22251319, 1.13418227, 1.58633379, ..., 0.30180313, 0.5581534 ,
#         0.96361241]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([6, 1, 1, 1, 7, 3, 6, 8, 3], dtype=int64))

# %%
z[27][6]
# Out:
# 3.1646194851713774

# %%
happiness_new=happiness[(z<3).all(axis=1)]
happiness_new
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 150            3.655         0.05141                   0.46534  0.77115
# 151            3.587         0.04324                   0.25812  0.85188
# 152            3.575         0.03084                   0.31982  0.30285
# 154            3.340         0.03656                   0.28665  0.35386
# 156            2.905         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
print(happiness.shape)
print(happiness_new.shape)
# Out:
# (158, 9)
# (149, 9)

# %% [markdown]
# # Percentage Data loss:

# %%
loss_percentage=(158-151)/158*100
print(loss_percentage)
# Out:
# 4.430379746835443

# %% [markdown]
# Divideing data into feature and vectors:

# %%
x=happiness_new.iloc[:,1:9]

# %%
x
# Out:
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 150         0.05141                   0.46534  0.77115
# 151         0.04324                   0.25812  0.85188
# 152         0.03084                   0.31982  0.30285
# 154         0.03656                   0.28665  0.35386
# 156         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
y=happiness_new.iloc[:,1]

# %%
y
# Out:
# 0      0.03411
# 1      0.04884
# 2      0.03328
# 3      0.03880
# 4      0.03553
#         ...
# 150    0.05141
# 151    0.04324
# 152    0.03084
# 154    0.03656
# 156    0.08658
# Name: Standard Error, Length: 149, dtype: float64

# %% [markdown]
# # Transforming the data to remove skewness:

# %%
from sklearn.preprocessing import power_transform
L=power_transform(x,method="yeo-johnson")

# %%
L
# Out:
# array([[-0.95033703,  1.49245411,  1.65888018, ...,  1.81762512,
#          0.65957854,  0.75525527],
#        [ 0.37856182,  1.19406711,  2.009125  , ...,  0.32967609,
#          1.56260401,  1.11116834],
#        [-1.04140135,  1.26661161,  1.73078531, ...,  1.95339954,
#          0.97722591,  0.70649452],
#        ...,
#        [-1.32081011, -1.36521585, -2.08738872, ..., -0.19284338,
#          1.13425805, -0.32711524],
#        [-0.69272644, -1.43304072, -2.01044288, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [ 2.17876604, -1.93874732, -1.9064101 , ..., -0.14727362,
#         -0.17248609, -0.55359235]])

# %%
for i in happiness_new:
    sns.distplot(happiness_new[i])
    plt.show()

# %% [markdown]
# # So here is outcome is in continious form so here we can use regression model(linear regression model):

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
x
# Out:
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 150         0.05141                   0.46534  0.77115
# 151         0.04324                   0.25812  0.85188
# 152         0.03084                   0.31982  0.30285
# 154         0.03656                   0.28665  0.35386
# 156         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
y
# Out:
# 0      0.03411
# 1      0.04884
# 2      0.03328
# 3      0.03880
# 4      0.03553
#         ...
# 150    0.05141
# 151    0.04324
# 152    0.03084
# 154    0.03656
# 156    0.08658
# Name: Standard Error, Length: 149, dtype: float64

# %%
x.shape
# Out:
# (149, 8)

# %%
y.shape
# Out:
# (149,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)

# %%
x_train.shape
# Out:
# (99, 8)

# %%
y_train.shape
# Out:
# (99,)

# %%
x_test.shape
# Out:
# (50, 8)

# %%
y_test.shape
# Out:
# (50,)

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 1.00000000e+00, -1.22510843e-17, -7.81043531e-19,  1.37107258e-17,
#         3.00597961e-18, -1.38605524e-17,  7.60964669e-18,  1.99385744e-19])

# %%
lm.intercept_
# Out:
# 2.0816681711721685e-17

# %%
lm.score(x_train,y_train)
# Out:
# 1.0

# %%
pred=lm.predict(x_test)

# %%
pred
# Out:
# array([0.03823, 0.03595, 0.0378 , 0.04524, 0.03363, 0.05051, 0.05099,
#        0.05061, 0.05051, 0.06607, 0.04585, 0.03751, 0.03868, 0.04083,
#        0.03729, 0.03938, 0.03608, 0.04013, 0.04615, 0.04758, 0.04168,
#        0.04934, 0.058  , 0.04678, 0.04828, 0.05141, 0.04742, 0.05648,
#        0.04528, 0.04539, 0.06476, 0.04076, 0.05018, 0.04454, 0.04267,
#        0.03077, 0.04114, 0.03512, 0.03553, 0.03557, 0.04734, 0.0464 ,
#        0.04934, 0.03499, 0.0347 , 0.06988, 0.05602, 0.0383 , 0.03225,
#        0.05232])

# %%
print("Predicted_result:-",pred)
print("\n")
print("Actual_score:-",y_test)
# Out:
# Predicted_result:- [0.03823 0.03595 0.0378  0.04524 0.03363 0.05051 0.05099 0.05061 0.05051
#  0.06607 0.04585 0.03751 0.03868 0.04083 0.03729 0.03938 0.03608 0.04013
#  0.04615 0.04758 0.04168 0.04934 0.058   0.04678 0.04828 0.05141 0.04742
#  0.05648 0.04528 0.04539 0.06476 0.04076 0.05018 0.04454 0.04267 0.03077
#  0.04114 0.03512 0.03553 0.03557 0.04734 0.0464  0.04934 0.03499 0.0347
#  0.06988 0.05602 0.0383  0.03225 0.05232]
#
#
# Actual_score:- 76     0.03823
# 18     0.03595
# 121    0.03780
# 81     0.04524
# 79     0.03363
# 32     0.05051
# 67     0.05099
# 145    0.05061
# 71     0.05051
# 85     0.06607
# 112    0.04585
# 12     0.03751
# 37     0.03868
# 9      0.04083
# 19     0.03729
# 58     0.03938
# 141    0.03608
# 72     0.04013
# 57     0.04615
# 136    0.04758
# 30     0.04168
# 127    0.04934
# 26     0.05800
# 132    0.04678
# 133    0.04828
# 150    0.05141
# 113    0.04742
# 104    0.05648
# 47     0.04528
# 31     0.04539
# 22     0.06476
# 15     0.04076
# ...

# %%
print("Error")
print("Mean_absolute_error:-",mean_absolute_error(y_test,pred))
print("Mean_squared_error:-",mean_squared_error(y_test,pred))
print("root_mean_squared_error:-",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Error
# Mean_absolute_error:- 8.743006318923108e-18
# Mean_squared_error:- 1.068891119134916e-34
# root_mean_squared_error:- 1.0338719065410937e-17

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 1.0
