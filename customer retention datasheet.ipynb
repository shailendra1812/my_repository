# %% [markdown]
# # E-retail factors for customer activation and retention: A case study from Indian e-commerce customers

# %%
# importing the important liberary:-

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sc
import warnings
warnings.filterwarnings("ignore")

# %%
# Print all columns inside the dataset:-

pd.pandas.set_option("display.max_columns",None)

# %%
# Print the data frame:-

datasheet=pd.read_excel("datasheet.xlsx")
datasheet.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
# Print all the matadata of the dataframe:-

datasheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# from the above information we get that:-
#
#     row=269
#
#     columns=71
#
# all the dataset having (obj) datatype except 4th columns "4 What is the Pin Code of where you shop online from?" it has (int64) datatye of value.

# %%
# find the null values inside the dataset:-

datasheet_null=[i for i in datasheet.columns if datasheet[i].isnull().sum()>1]
datasheet_null
# Out:
# []

# %% [markdown]
# So from the above code we find an empty list so there is no null values is present inside the dataset.

# %% [markdown]
# # For Numerical value:

# %%
datasheet_num=[i for i in datasheet.columns if datasheet[i].dtype!="O"]
print(datasheet_num)
print("\n")
print("Length of numerical_val:",len(datasheet_num))
print("\n")
datasheet[datasheet_num]
# Out:
# ['4 What is the Pin Code of where you shop online from?']
#
#
# Length of numerical_val: 1
#      4 What is the Pin Code of where you shop online from?
# 0                                               110009
# 1                                               110030
# 2                                               201308
# 3                                               132001
# 4                                               530068
# ..                                                 ...
# 264                                             173212
# 265                                             201008
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
# [269 rows x 1 columns]

# %% [markdown]
# for the above we found that there are only one columns which have (int64) kind of data.
# which have 269 row and only one column.

# %% [markdown]
# # Checking null values inside the numerical dataset:

# %%
datasheet[datasheet_num].isnull().sum()
# Out:
# 4 What is the Pin Code of where you shop online from?    0
# dtype: int64

# %% [markdown]
# so here we can see that there is no null value inside the num values.

# %% [markdown]
# # For Catagorical Values:

# %%
datasheet_cat=[i for i in datasheet.columns if datasheet[i].dtype=="O"]
print(datasheet_cat)
print("\n")
print("Length of catgorical_val:",len(datasheet_cat))
print("\n")
datasheet[datasheet_cat].head()
# Out:
# ['1Gender of respondent', '2 How old are you? ', '3 Which city do you shop online from?', '5 Since How Long You are Shopping Online ?', '6 How many times you have made an online purchase in the past 1 year?', '7 How do you access the internet while shopping on-line?', '8 Which device do you use to access the online shopping?', '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ', '10 What is the operating system (OS) of your device?\t\t\t\t                                          ', '11 What browser do you run on your device to access the website?\t\t\t                                                          ', '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ', '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ', '14 How much time do you explore the e-
# ...

# %% [markdown]
# # Find the null values inside the catagorical value:

# %%
datasheet[datasheet_cat].isnull().sum()
# Out:
# 1Gender of respondent                                                    0
# 2 How old are you?                                                       0
# 3 Which city do you shop online from?                                    0
# 5 Since How Long You are Shopping Online ?                               0
# 6 How many times you have made an online purchase in the past 1 year?    0
#                                                                         ..
# Longer delivery period                                                   0
# Change in website/Application design                                     0
# Frequent disruption when moving from one page to another                 0
# Website is as efficient as before                                        0
# Which of the Indian online retailer would you recommend to a friend?     0
# Length: 70, dtype: int64

# %% [markdown]
# form the above we get that there is no null value inside the catagorical value.

# %% [markdown]
# # Find the unique value from the dataset:

# %%
for i in datasheet_cat:
    print("feature is {}".format(i))
    print("\n")
    print("Unique feature is:",datasheet[i].unique())
    print("\n")
    print("In feature {} is and number of catagoery are {}".format(i,len(datasheet[i].unique())))
    print("\n")
# Out:
# feature is 1Gender of respondent
#
#
# Unique feature is: ['Male' 'Female']
#
#
# In feature 1Gender of respondent is and number of catagoery are 2
#
#
# feature is 2 How old are you?
#
#
# Unique feature is: ['31-40 years' '21-30 years' '41-50 yaers' 'Less than 20 years'
#  '51 years and above']
#
#
# In feature 2 How old are you?  is and number of catagoery are 5
#
#
# feature is 3 Which city do you shop online from?
#
#
# Unique feature is: ['Delhi' 'Greater Noida' 'Karnal ' 'Bangalore ' 'Noida' 'Solan'
#  'Moradabad' 'Gurgaon ' 'Merrut' 'Ghaziabad' 'Bulandshahr']
#
#
# In feature 3 Which city do you shop online from? is and number of catagoery are 11
#
#
# feature is 5 Since How Long You are Shopping Online ?
#
#
# Unique feature is: ['Above 4 years' '3-4 years' '2-3 years' 'Less than 1 year' '1-2 years']
#
#
# In feature 5 Since How Long You are Shopping Online ? is and number of catagoery are 5
#
#
# ...

# %% [markdown]
# some columns are which have 11 unique value while some other are like that which have only 2 unique value.

# %% [markdown]
# # Plot the dataset and count the each unique feature:

# %%
for i in datasheet_cat:
    sns.countplot(datasheet[i])
    plt.xticks(rotation=90)
    plt.title(i)
    plt.show()
    print(i)
    print(datasheet[i].value_counts())
    print("\n")
# Out:
# 1Gender of respondent
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64
# 2 How old are you?
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64
# 3 Which city do you shop online from?
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64
# 5 Since How Long You are Shopping Online ?
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64
# 6 How many times you have made an online purchase in the past 1 year?
# Less than 10 times    114
# ...

# %% [markdown]
# Female customer is more than man.
#
# 31-40 years age group are more than any one.
#
# Delhi city has the more coustmer.
#
# Most of the customer are shopping scince more 4 year
#
# In one year most of the preson shoopped less than 10n time.
#
# Most of the coustmer uses mobile internate.
#
# Mostely smart phone are uses for online shopping.
#
# Screen size is different for the different mobile.
#
# Operating system window is mostely used in.
#
# Google chrome are mostely used.
#
# Google search is mostely used.
#
# After search most of the people used search engine for the shopping.
#
# Most of the coustmer spend more than 15 min in online store.
#
# Credite/debit card is mostely used for shopping purpose.
#
# If anybody purchase anything than it abdoned for sometime.
#
# In batter alternate offer we abondon the bag.
#
# The contant on the website is easily understandable.most of the people are strongely agree.
#
# Information on similar product to the one highlighted  is important for product comparison-Strongly agree.
#
# Complete information on listed seller and product being offered is important for purchase decision-Agree.
#
# All relevant information on listed products must be stated clearly-Agree.
#
# Ease of navigation in website-Strongly agree.
#
# Loading and processing speed-Strongly agree.
#
# User friendly Interface of the website-Strongly agree.
#
# Convenient Payment methods-Strongly agree.
#
# Trust that the online retail store will fulfill its part of the transaction at the stipulated time-Strongly agree.
#
# Empathy (readiness to assist with queries) towards the customers-Strongly agree.
#
# Being able to guarantee the privacy of the customer-Strongly agree.
#
# Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)-Strongly agree.
#
# Online shopping gives monetary benefit and discounts-Strongly agree.
#
# Enjoyment is derived from shopping online-Strongly agree.
#
# Shopping online is convenient and flexible-Strongly agree.
#
# Return and replacement policy of the e-tailer is important for purchase decision-Strongly agree.
#
# Gaining access to loyalty programs is a benefit of shopping online-Strongly agree.
#
# Displaying quality Information on the website improves satisfaction of customersp-Strongly agree.
#
# User derive satisfaction while shopping on a good quality website or application-Strongly agree.
#
# Net Benefit derived from shopping online can lead to users satisfaction-Strongly agree.
#
# User satisfaction cannot exist without trust-Strongly agree.
#
# Offering a wide variety of listed product in several category-Strongly agree.
#
# Provision of complete and relevant product information-Strongly agree.
#
# Monetary savings-Strongly agree.
#
# The Convenience of patronizing the online retailer-Agree.
#
# Shopping on the website gives you the sense of adventure-Agree.
#
# Shopping on your preferred e-tailer enhances your social status-indifferent.
#
# You feel gratification shopping on your favorite e-tailer-indifferent.
#
# Shopping on the website helps you fulfill certain roles-Agree
#
# Getting value for money spent-Agree
#
# From the following, tick any (or all) of the online retailers you have shopped from-Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com
#
# Easy to use website or application-Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com
#
# Visual appealing web-page layout-Amazon.in, Flipkart.com
#
# Wild variety of product on offer-Amazon.in, Flipkart.com
#
# Complete, relevant description information of products-Amazon.in, Flipkart.com
#
# Fast loading website speed of website and application-Amazon.in
#
# Reliability of the website or application-Amazon.in
#
# Quickness to complete purchase-Amazon.com
#
# Availability of several payment options-Amazon.in, Flipkart.com
#
# Speedy order delivery-Amazon.in
#
# Privacy of customers’ information-Amazon.in
#
# Security of customer financial information-Amazon.in
#
# Perceived Trustworthiness-Amazon.in
#
# Presence of online assistance through multi-channel-Amazon.in, Flipkart.com, Myntra.com, Snapdeal
#
# Longer time to get logged in (promotion, sales period)-Amazon.in
#
# Longer time in displaying graphics and photos (promotion, sales period)-Amazon.in, Flipkart.com
#
# Late declaration of price (promotion, sales period)-Myntra.com
#
# Longer page loading time (promotion, sales period)-Myntra.com
#
# Limited mode of payment on most products (promotion, sales period)-Snapdeal.com
#
# Longer delivery period-Paytm.com
#
# Change in website/Application design-Amazon.in
#
# Frequent disruption when moving from one page to another-Amazon.in
#
# Website is as efficient as before-Amazon.in
#
# Which of the Indian online retailer would you recommend to a friend?-Amazon.in

# %% [markdown]
# # Gender Vs Age:

# %%
sns.countplot(x="2 How old are you? ",data=datasheet,hue="1Gender of respondent")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From the above information we get that:-
#
#     female user is more than the male user.
#
#     from age 21-30 year having more female.

# %% [markdown]
# # Gender Vs City:

# %%
sns.countplot(x="3 Which city do you shop online from?",data=datasheet,hue="1Gender of respondent")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# from the above information we get that:
#
#     Only Delhi and Noida has more male coustmer.
#
#     Rest of the place female is more.
#
#     Solan have only male coustmer.
#
#     Muradabad and Bulandsher have only female coustmer in short ratio.

# %%
df=(datasheet["1Gender of respondent"]=="Male") & (datasheet["2 How old are you? "]=="31-40 years")

# %%
datasheet.loc[df]
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 10                   Male         31-40 years
# 16                   Male         31-40 years
# 21                   Male         31-40 years
# 27                   Male         31-40 years
# 31                   Male         31-40 years
# 32                   Male         31-40 years
# 36                   Male         31-40 years
# 41                   Male         31-40 years
# 62                   Male         31-40 years
# 66                   Male         31-40 years
# 71                   Male         31-40 years
# 86                   Male         31-40 years
# 111                  Male         31-40 years
# 112                  Male         31-40 years
# 113                  Male         31-40 years
# 132                  Male         31-40 years
# 133                  Male         31-40 years
# 134                  Male         31-40 years
# ...

# %%
datasheet.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
sns.countplot(x="1Gender of respondent",data=datasheet,hue="2 How old are you? ")
